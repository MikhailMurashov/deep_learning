# %%
import pandas
from keras_preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping
from keras.utils import plot_model
from keras.models import load_model
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# %% [markdown]
# Обозначим глобальные переменные. Входной размер изображений - 224х224

# %%
input_shape = (224, 224)
categories_num = 37
batch_size = 32

# %% [markdown]
# Создадим генераторы для обучения сети. Data augmentation будет применться только в одном эксперименте.

# %%
train_data = pandas.read_csv('../train_pets.csv', usecols=['Category', 'Path'])
val_data = pandas.read_csv('../val_pets.csv', usecols=['Category', 'Path'])

train_datagen = ImageDataGenerator(
        rescale=1. / 255,
#         rotation_range=10,
#         zoom_range=0.1,
#         brightness_range=(0.7, 1.3),
#         horizontal_flip=True
)
val_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_data,
        directory='.',
        x_col='Path',
        y_col='Category',
        class_mode='categorical',
        target_size=input_shape,
        interpolation='bicubic',
        batch_size=batch_size)

val_generator = val_datagen.flow_from_dataframe(
        dataframe=val_data,
        directory='.',
        x_col='Path',
        y_col='Category',
        class_mode='categorical',
        target_size=input_shape,
        interpolation='bicubic',
        batch_size=batch_size)
# Out:
# Found 6434 validated image filenames belonging to 37 classes.
# Found 333 validated image filenames belonging to 37 classes.

# %%
def plot_history(histories, save=False, folder=""):
    # Plot training & validation accuracy values
    plt.figure(1)
    for i in range(len(histories)):
        plt.plot(histories[i].history['categorical_accuracy'])
        plt.plot(histories[i].history['val_categorical_accuracy'])
        plt.title('Model accuracy')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Test'], loc='upper left')

    # Plot training & validation loss values
    plt.figure(2)
    for i in range(len(histories)):
        plt.plot(histories[i].history['loss'])
        plt.plot(histories[i].history['val_loss'])
        plt.title('Model loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Test'], loc='upper left')

    plt.show()

# %% [markdown]
# Метод для создания модели. Возможны следующие варианты:
#  - стек простых сверточных слоев с активацией ReLU
#  - слой *BatchNormalization* после каждой вертки
#  - слой *Dropout(0.7)* перед слоем классификации
#  - слой *GlobalAveragePooling2D* вместо дополнительного полносвязного слоя
#
# Также присутствует параметр *lr* для корректировки learning rate в оптимизаторе Adam.

# %%
from keras import Sequential
from keras.layers import *
from keras.metrics import categorical_accuracy
from keras.optimizers import Adam
from keras.utils import plot_model

def conv_model(size=1, lr=0.001, use_dropout=False, use_batchnorm=False, use_globalpool=False):
    model = Sequential()
    image_inputs = Input(shape=(input_shape[0], input_shape[1], 3,))
    
    model.add(Conv2D(64, (7, 7), strides=(2, 2), padding='same',
                     input_shape=(input_shape[0], input_shape[1], 3,)))
    if use_batchnorm:
        model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(MaxPooling2D((2, 2)))
    
    for i in range(size-1):
        model.add(Conv2D(128*(2**i), (3, 3), padding='same'))
        if use_batchnorm:
            model.add(BatchNormalization())
        model.add(Activation('relu'))
                      
        model.add(Conv2D(128*(2**i), (3, 3), padding='same'))
        if use_batchnorm:
            model.add(BatchNormalization())
        model.add(Activation('relu'))
                      
        model.add(MaxPooling2D((2, 2)))

    if use_globalpool:
        model.add(GlobalAveragePooling2D())
    else:
        model.add(Flatten())
        model.add(Dense(256, activation='relu'))
    
    if use_dropout:
        model.add(Dropout(0.7))     
    
    model.add(Dense(units=categories_num, activation='softmax'))
    
    model.compile(optimizer=Adam(lr=lr), loss='categorical_crossentropy', metrics=[categorical_accuracy])
    return model

# %% [markdown]
# ### Первый вариант модели

# %%
model = conv_model(size=2, lr=0.0003, use_dropout=False, use_batchnorm=False, use_globalpool=False)
model.summary()

# plot_model(model, to_file='size=2,lr=0.001,use_dropout=False,use_batchnorm=False,use_globalpool=False.png',
#            show_shapes=False, show_layer_names=False)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 112, 112, 64)      9472
# _________________________________________________________________
# activation_7 (Activation)    (None, 112, 112, 64)      0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 56, 56, 128)       73856
# _________________________________________________________________
# activation_8 (Activation)    (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 56, 56, 128)       147584
# _________________________________________________________________
# activation_9 (Activation)    (None, 56, 56, 128)       0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 100352)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               25690368
# _________________________________________________________________
# dense_6 (Dense)              (None, 37)                9509
# =================================================================
# Total params: 25,930,789
# Trainable params: 25,930,789
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stop = EarlyStopping(patience=10)

history_1 = model.fit_generator(
            generator=train_generator,
            steps_per_epoch=train_generator.n // batch_size,
            validation_data=val_generator,
            validation_steps=val_generator.n // batch_size,
            epochs=100,
            verbose=2,
            callbacks=[early_stop])

plot_history([history_1])
# Out:
# Epoch 1/100
#  - 19s - loss: 3.6011 - categorical_accuracy: 0.0392 - val_loss: 3.5296 - val_categorical_accuracy: 0.0465
# Epoch 2/100
#  - 16s - loss: 3.2629 - categorical_accuracy: 0.1222 - val_loss: 3.1931 - val_categorical_accuracy: 0.1362
# Epoch 3/100
#  - 16s - loss: 2.6147 - categorical_accuracy: 0.2836 - val_loss: 3.4794 - val_categorical_accuracy: 0.1462
# Epoch 4/100
#  - 16s - loss: 1.6516 - categorical_accuracy: 0.5348 - val_loss: 3.8540 - val_categorical_accuracy: 0.1827
# Epoch 5/100
#  - 16s - loss: 0.6590 - categorical_accuracy: 0.8117 - val_loss: 5.6533 - val_categorical_accuracy: 0.1794
# Epoch 6/100
#  - 16s - loss: 0.1812 - categorical_accuracy: 0.9557 - val_loss: 6.9299 - val_categorical_accuracy: 0.1362
# Epoch 7/100
#  - 16s - loss: 0.0586 - categorical_accuracy: 0.9863 - val_loss: 7.2820 - val_categorical_accuracy: 0.1628
# Epoch 8/100
#  - 16s - loss: 0.0332 - categorical_accuracy: 0.9928 - val_loss: 7.6288 - val_categorical_accuracy: 0.2027
# Epoch 9/100
#  - 17s - loss: 0.0315 - categorical_accuracy: 0.9930 - val_loss: 8.1955 - val_categorical_accuracy: 0.1628
# Epoch 10/100
#  - 17s - loss: 0.0639 - categorical_accuracy: 0.9827 - val_loss: 7.8272 - val_categorical_accuracy: 0.1437
# Epoch 11/100
#  - 17s - loss: 0.0895 - categorical_accuracy: 0.9748 - val_loss: 8.0996 - val_categorical_accuracy: 0.1661
# Epoch 12/100
#  - 16s - loss: 0.0389 - categorical_accuracy: 0.9913 - val_loss: 8.6317 - val_categorical_accuracy: 0.1561

# %% [markdown]
# Наблюдается сильное переобучение. Попробуем использовать батч нормализацию и замеим слой Dense на GlobalPooling. Также попробуем увеличить общее количество слоев.

# %% [markdown]
# ### Второй вариант модели

# %%
model = conv_model(size=3, lr=0.0003, use_dropout=False, use_batchnorm=True, use_globalpool=True)
model.summary()

# plot_model(model, to_file='size=3,lr=0.001,use_dropout=False,use_batchnorm=True,use_globalpool=True.png',
#            show_shapes=False, show_layer_names=False)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 112, 112, 64)      9472
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 112, 112, 64)      256
# _________________________________________________________________
# activation_15 (Activation)   (None, 112, 112, 64)      0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 56, 56, 128)       73856
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 56, 56, 128)       512
# _________________________________________________________________
# activation_16 (Activation)   (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 56, 56, 128)       147584
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 56, 56, 128)       512
# _________________________________________________________________
# activation_17 (Activation)   (None, 56, 56, 128)       0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 28, 28, 256)       295168
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 28, 28, 256)       1024
# _________________________________________________________________
# activation_18 (Activation)   (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 28, 28, 256)       590080
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# activation_19 (Activation)   (None, 28, 28, 256)       0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 14, 14, 256)       0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 37)                9509
# =================================================================
# Total params: 1,128,997
# Trainable params: 1,127,333
# Non-trainable params: 1,664
# _________________________________________________________________

# %%
early_stop = EarlyStopping(patience=10)

history_2 = model.fit_generator(
            generator=train_generator,
            steps_per_epoch=train_generator.n // batch_size,
            validation_data=val_generator,
            validation_steps=val_generator.n // batch_size,
            epochs=100,
            verbose=2,
            callbacks=[early_stop])

plot_history([history_2])
# Out:
# Epoch 1/100
#  - 23s - loss: 3.4769 - categorical_accuracy: 0.0798 - val_loss: 3.5550 - val_categorical_accuracy: 0.0594
# Epoch 2/100
#  - 21s - loss: 3.1910 - categorical_accuracy: 0.1308 - val_loss: 4.3196 - val_categorical_accuracy: 0.0930
# Epoch 3/100
#  - 20s - loss: 2.9976 - categorical_accuracy: 0.1900 - val_loss: 3.7294 - val_categorical_accuracy: 0.0465
# Epoch 4/100
#  - 20s - loss: 2.8465 - categorical_accuracy: 0.2245 - val_loss: 3.4832 - val_categorical_accuracy: 0.1196
# Epoch 5/100
#  - 20s - loss: 2.7102 - categorical_accuracy: 0.2545 - val_loss: 3.4140 - val_categorical_accuracy: 0.1196
# Epoch 6/100
#  - 20s - loss: 2.5861 - categorical_accuracy: 0.2898 - val_loss: 3.4414 - val_categorical_accuracy: 0.0698
# Epoch 7/100
#  - 20s - loss: 2.4747 - categorical_accuracy: 0.3089 - val_loss: 4.6221 - val_categorical_accuracy: 0.0731
# Epoch 8/100
#  - 20s - loss: 2.3631 - categorical_accuracy: 0.3492 - val_loss: 3.8067 - val_categorical_accuracy: 0.1761
# Epoch 9/100
#  - 20s - loss: 2.2779 - categorical_accuracy: 0.3749 - val_loss: 2.9679 - val_categorical_accuracy: 0.2159
# Epoch 10/100
#  - 20s - loss: 2.1914 - categorical_accuracy: 0.3951 - val_loss: 2.7470 - val_categorical_accuracy: 0.2525
# Epoch 11/100
#  - 20s - loss: 2.0930 - categorical_accuracy: 0.4220 - val_loss: 4.4199 - val_categorical_accuracy: 0.1296
# Epoch 12/100
#  - 20s - loss: 1.9905 - categorical_accuracy: 0.4454 - val_loss: 2.8832 - val_categorical_accuracy: 0.2469
# Epoch 13/100
#  - 20s - loss: 1.9120 - categorical_accuracy: 0.4703 - val_loss: 2.9100 - val_categorical_accuracy: 0.1794
# Epoch 14/100
#  - 20s - loss: 1.8570 - categorical_accuracy: 0.4831 - val_loss: 3.7094 - val_categorical_accuracy: 0.1495
# Epoch 15/100
#  - 19s - loss: 1.8020 - categorical_accuracy: 0.5016 - val_loss: 3.0040 - val_categorical_accuracy: 0.2126
# Epoch 16/100
#  - 19s - loss: 1.7109 - categorical_accuracy: 0.5243 - val_loss: 3.0273 - val_categorical_accuracy: 0.2625
# Epoch 17/100
#  - 19s - loss: 1.6419 - categorical_accuracy: 0.5474 - val_loss: 2.8030 - val_categorical_accuracy: 0.2591
# Epoch 18/100
#  - 19s - loss: 1.5700 - categorical_accuracy: 0.5572 - val_loss: 3.1764 - val_categorical_accuracy: 0.2326
# Epoch 19/100
#  - 19s - loss: 1.5068 - categorical_accuracy: 0.5804 - val_loss: 3.3554 - val_categorical_accuracy: 0.2658
# Epoch 20/100
#  - 19s - loss: 1.4562 - categorical_accuracy: 0.5967 - val_loss: 2.5703 - val_categorical_accuracy: 0.3023
# Epoch 21/100
#  - 19s - loss: 1.3800 - categorical_accuracy: 0.6177 - val_loss: 2.9253 - val_categorical_accuracy: 0.2492
# Epoch 22/100
#  - 19s - loss: 1.3330 - categorical_accuracy: 0.6328 - val_loss: 2.2224 - val_categorical_accuracy: 0.3322
# Epoch 23/100
#  - 19s - loss: 1.2671 - categorical_accuracy: 0.6542 - val_loss: 2.7396 - val_categorical_accuracy: 0.3094
# Epoch 24/100
#  - 20s - loss: 1.2428 - categorical_accuracy: 0.6605 - val_loss: 2.2956 - val_categorical_accuracy: 0.3987
# Epoch 25/100
#  - 19s - loss: 1.1941 - categorical_accuracy: 0.6648 - val_loss: 3.7021 - val_categorical_accuracy: 0.1495
# Epoch 26/100
#  - 19s - loss: 1.1129 - categorical_accuracy: 0.6998 - val_loss: 3.0064 - val_categorical_accuracy: 0.2658
# Epoch 27/100
#  - 20s - loss: 1.0721 - categorical_accuracy: 0.7071 - val_loss: 3.1539 - val_categorical_accuracy: 0.3189
# Epoch 28/100
#  - 19s - loss: 1.0140 - categorical_accuracy: 0.7307 - val_loss: 2.5379 - val_categorical_accuracy: 0.2691
# Epoch 29/100
#  - 19s - loss: 0.9684 - categorical_accuracy: 0.7478 - val_loss: 2.9656 - val_categorical_accuracy: 0.2724
# Epoch 30/100
#  - 20s - loss: 0.9113 - categorical_accuracy: 0.7593 - val_loss: 2.2491 - val_categorical_accuracy: 0.3987
# Epoch 31/100
#  - 20s - loss: 0.8795 - categorical_accuracy: 0.7736 - val_loss: 2.5872 - val_categorical_accuracy: 0.3156
# Epoch 32/100
#  - 20s - loss: 0.8280 - categorical_accuracy: 0.7817 - val_loss: 2.6032 - val_categorical_accuracy: 0.3754

# %% [markdown]
# Переобучение снизилось. Точность на тренировочной выборке возросла до 0,68. Сходится модель намного быстрее благодаря слоям батч нормализации. Попробуем добавть дроаут перед слоем классификации, чтобы еще снизить переобучение.

# %%
model.save('2.h5')

# %% [markdown]
# ### Третий вариант модели

# %%
model = conv_model(size=3, lr=0.001, use_dropout=True, use_batchnorm=True, use_globalpool=True)
model.summary()

plot_model(model, to_file='size=3,lr=0,001,use_dropout=True,use_batchnorm=True,use_globalpool=True',
           show_shapes=False, show_layer_names=False)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_42 (Conv2D)           (None, 112, 112, 64)      9472
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 112, 112, 64)      256
# _________________________________________________________________
# activation_42 (Activation)   (None, 112, 112, 64)      0
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 56, 56, 128)       73856
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 56, 56, 128)       512
# _________________________________________________________________
# activation_43 (Activation)   (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 56, 56, 128)       147584
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 56, 56, 128)       512
# _________________________________________________________________
# activation_44 (Activation)   (None, 56, 56, 128)       0
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 28, 28, 256)       295168
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# activation_45 (Activation)   (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 28, 28, 256)       590080
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# activation_46 (Activation)   (None, 28, 28, 256)       0
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 14, 14, 256)       0
# _________________________________________________________________
# global_average_pooling2d_6 ( (None, 256)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 37)                9509
# =================================================================
# Total params: 1,128,997
# Trainable params: 1,127,333
# Non-trainable params: 1,664
# _________________________________________________________________

# %%
early_stop = EarlyStopping(patience=10)

history_2 = model.fit_generator(
            generator=train_generator,
            steps_per_epoch=train_generator.n // batch_size,
            validation_data=val_generator,
            validation_steps=val_generator.n // batch_size,
            epochs=100,
            verbose=2,
            callbacks=[early_stop])

plot_history([history_2])
# Out:
# Epoch 1/100
#  - 22s - loss: 3.9632 - categorical_accuracy: 0.0359 - val_loss: 3.9728 - val_categorical_accuracy: 0.0266
# Epoch 2/100
#  - 17s - loss: 3.7023 - categorical_accuracy: 0.0431 - val_loss: 3.9719 - val_categorical_accuracy: 0.0365
# Epoch 3/100
#  - 17s - loss: 3.5835 - categorical_accuracy: 0.0491 - val_loss: 3.6195 - val_categorical_accuracy: 0.0399
# Epoch 4/100
#  - 17s - loss: 3.5004 - categorical_accuracy: 0.0648 - val_loss: 4.2606 - val_categorical_accuracy: 0.0266
# Epoch 5/100
#  - 18s - loss: 3.4227 - categorical_accuracy: 0.0810 - val_loss: 3.5879 - val_categorical_accuracy: 0.0500
# Epoch 6/100
#  - 18s - loss: 3.3803 - categorical_accuracy: 0.0846 - val_loss: 3.6173 - val_categorical_accuracy: 0.0432
# Epoch 7/100
#  - 17s - loss: 3.2826 - categorical_accuracy: 0.1059 - val_loss: 3.6531 - val_categorical_accuracy: 0.0432
# Epoch 8/100
#  - 18s - loss: 3.2255 - categorical_accuracy: 0.1154 - val_loss: 4.3772 - val_categorical_accuracy: 0.0365
# Epoch 9/100
#  - 18s - loss: 3.1580 - categorical_accuracy: 0.1345 - val_loss: 3.6143 - val_categorical_accuracy: 0.0731
# Epoch 10/100
#  - 17s - loss: 3.0483 - categorical_accuracy: 0.1570 - val_loss: 3.5507 - val_categorical_accuracy: 0.0498
# Epoch 11/100
#  - 17s - loss: 2.9780 - categorical_accuracy: 0.1656 - val_loss: 4.3531 - val_categorical_accuracy: 0.0664
# Epoch 12/100
#  - 17s - loss: 2.9223 - categorical_accuracy: 0.1877 - val_loss: 4.2031 - val_categorical_accuracy: 0.1163
# Epoch 13/100
#  - 17s - loss: 2.8598 - categorical_accuracy: 0.1954 - val_loss: 4.9254 - val_categorical_accuracy: 0.0598
# Epoch 14/100
#  - 17s - loss: 2.7904 - categorical_accuracy: 0.2150 - val_loss: 2.9441 - val_categorical_accuracy: 0.1960
# Epoch 15/100
#  - 17s - loss: 2.7133 - categorical_accuracy: 0.2278 - val_loss: 3.1437 - val_categorical_accuracy: 0.1794
# Epoch 16/100
#  - 17s - loss: 2.6146 - categorical_accuracy: 0.2545 - val_loss: 4.0398 - val_categorical_accuracy: 0.1062
# Epoch 17/100
#  - 18s - loss: 2.6177 - categorical_accuracy: 0.2509 - val_loss: 4.3204 - val_categorical_accuracy: 0.1096
# Epoch 18/100
#  - 19s - loss: 2.5483 - categorical_accuracy: 0.2749 - val_loss: 2.9555 - val_categorical_accuracy: 0.1960
# Epoch 19/100
#  - 19s - loss: 2.4608 - categorical_accuracy: 0.2876 - val_loss: 3.0605 - val_categorical_accuracy: 0.1595
# Epoch 20/100
#  - 18s - loss: 2.4063 - categorical_accuracy: 0.3043 - val_loss: 2.9559 - val_categorical_accuracy: 0.1927
# Epoch 21/100
#  - 19s - loss: 2.3768 - categorical_accuracy: 0.3085 - val_loss: 5.3168 - val_categorical_accuracy: 0.1362
# Epoch 22/100
#  - 17s - loss: 2.3151 - categorical_accuracy: 0.3302 - val_loss: 2.4412 - val_categorical_accuracy: 0.3289
# Epoch 23/100
#  - 17s - loss: 2.2483 - categorical_accuracy: 0.3444 - val_loss: 2.8188 - val_categorical_accuracy: 0.2292
# Epoch 24/100
#  - 18s - loss: 2.2302 - categorical_accuracy: 0.3428 - val_loss: 2.3435 - val_categorical_accuracy: 0.3256
# Epoch 25/100
#  - 19s - loss: 2.1324 - categorical_accuracy: 0.3738 - val_loss: 2.8150 - val_categorical_accuracy: 0.2591
# Epoch 26/100
#  - 19s - loss: 2.0870 - categorical_accuracy: 0.3808 - val_loss: 2.6278 - val_categorical_accuracy: 0.2359
# Epoch 27/100
#  - 18s - loss: 2.0346 - categorical_accuracy: 0.4010 - val_loss: 4.0224 - val_categorical_accuracy: 0.1812
# Epoch 28/100
#  - 17s - loss: 2.0229 - categorical_accuracy: 0.3937 - val_loss: 2.4501 - val_categorical_accuracy: 0.2890
# Epoch 29/100
#  - 17s - loss: 1.9359 - categorical_accuracy: 0.4279 - val_loss: 2.1109 - val_categorical_accuracy: 0.4219
# Epoch 30/100
#  - 17s - loss: 1.8990 - categorical_accuracy: 0.4313 - val_loss: 2.5512 - val_categorical_accuracy: 0.3056
# Epoch 31/100
#  - 17s - loss: 1.8212 - categorical_accuracy: 0.4487 - val_loss: 2.0132 - val_categorical_accuracy: 0.3721
# Epoch 32/100
#  - 17s - loss: 1.7885 - categorical_accuracy: 0.4653 - val_loss: 2.2530 - val_categorical_accuracy: 0.3953
# Epoch 33/100
#  - 17s - loss: 1.7607 - categorical_accuracy: 0.4683 - val_loss: 2.1436 - val_categorical_accuracy: 0.4319
# Epoch 34/100
#  - 17s - loss: 1.6633 - categorical_accuracy: 0.4983 - val_loss: 2.2067 - val_categorical_accuracy: 0.3455
# Epoch 35/100
#  - 17s - loss: 1.6200 - categorical_accuracy: 0.5115 - val_loss: 1.7621 - val_categorical_accuracy: 0.4684
# Epoch 36/100
#  - 17s - loss: 1.6994 - categorical_accuracy: 0.4927 - val_loss: 1.8095 - val_categorical_accuracy: 0.4718
# Epoch 37/100
#  - 17s - loss: 1.5895 - categorical_accuracy: 0.5154 - val_loss: 1.8613 - val_categorical_accuracy: 0.4485
# Epoch 38/100
#  - 17s - loss: 1.5159 - categorical_accuracy: 0.5344 - val_loss: 1.7906 - val_categorical_accuracy: 0.4813
# Epoch 39/100
#  - 17s - loss: 1.4742 - categorical_accuracy: 0.5474 - val_loss: 2.7002 - val_categorical_accuracy: 0.2957
# Epoch 40/100
#  - 18s - loss: 1.4570 - categorical_accuracy: 0.5521 - val_loss: 1.7325 - val_categorical_accuracy: 0.5050
# Epoch 41/100
#  - 17s - loss: 1.4401 - categorical_accuracy: 0.5580 - val_loss: 1.6325 - val_categorical_accuracy: 0.4684
# Epoch 42/100
#  - 18s - loss: 1.3886 - categorical_accuracy: 0.5759 - val_loss: 1.6460 - val_categorical_accuracy: 0.5216
# Epoch 43/100
#  - 17s - loss: 1.3201 - categorical_accuracy: 0.5919 - val_loss: 2.9292 - val_categorical_accuracy: 0.3422
# Epoch 44/100
#  - 18s - loss: 1.2832 - categorical_accuracy: 0.6048 - val_loss: 1.4917 - val_categorical_accuracy: 0.5781
# Epoch 45/100
#  - 18s - loss: 1.2119 - categorical_accuracy: 0.6259 - val_loss: 1.5414 - val_categorical_accuracy: 0.4917
# Epoch 46/100
#  - 17s - loss: 1.1779 - categorical_accuracy: 0.6367 - val_loss: 2.5172 - val_categorical_accuracy: 0.3289
# Epoch 47/100
#  - 17s - loss: 1.2081 - categorical_accuracy: 0.6314 - val_loss: 1.8336 - val_categorical_accuracy: 0.4884
# Epoch 48/100
#  - 17s - loss: 1.1686 - categorical_accuracy: 0.6502 - val_loss: 1.4983 - val_categorical_accuracy: 0.5581
# Epoch 49/100
#  - 17s - loss: 1.1055 - categorical_accuracy: 0.6542 - val_loss: 1.3799 - val_categorical_accuracy: 0.5781
# Epoch 50/100
#  - 17s - loss: 1.1073 - categorical_accuracy: 0.6550 - val_loss: 2.7586 - val_categorical_accuracy: 0.3588
# Epoch 51/100
#  - 17s - loss: 1.1240 - categorical_accuracy: 0.6577 - val_loss: 1.4925 - val_categorical_accuracy: 0.5615
# Epoch 52/100
#  - 17s - loss: 1.0096 - categorical_accuracy: 0.6962 - val_loss: 1.9524 - val_categorical_accuracy: 0.4651
# Epoch 53/100
#  - 17s - loss: 0.9560 - categorical_accuracy: 0.7060 - val_loss: 1.6277 - val_categorical_accuracy: 0.5349
# Epoch 54/100
#  - 18s - loss: 1.0469 - categorical_accuracy: 0.6835 - val_loss: 1.4946 - val_categorical_accuracy: 0.5581
# Epoch 55/100
#  - 17s - loss: 0.9448 - categorical_accuracy: 0.7128 - val_loss: 1.3871 - val_categorical_accuracy: 0.5681
# Epoch 56/100
#  - 17s - loss: 0.8902 - categorical_accuracy: 0.7292 - val_loss: 1.4152 - val_categorical_accuracy: 0.5515
# Epoch 57/100
#  - 17s - loss: 0.9306 - categorical_accuracy: 0.7146 - val_loss: 1.5815 - val_categorical_accuracy: 0.5482
# Epoch 58/100
#  - 17s - loss: 0.8661 - categorical_accuracy: 0.7334 - val_loss: 1.3036 - val_categorical_accuracy: 0.5914
# Epoch 59/100
#  - 17s - loss: 0.9042 - categorical_accuracy: 0.7225 - val_loss: 1.2747 - val_categorical_accuracy: 0.6279
# Epoch 60/100
#  - 17s - loss: 0.8180 - categorical_accuracy: 0.7441 - val_loss: 1.4818 - val_categorical_accuracy: 0.5750
# Epoch 61/100
#  - 17s - loss: 0.7705 - categorical_accuracy: 0.7629 - val_loss: 1.3071 - val_categorical_accuracy: 0.6213
# Epoch 62/100
#  - 17s - loss: 0.7635 - categorical_accuracy: 0.7653 - val_loss: 1.3500 - val_categorical_accuracy: 0.6047
# Epoch 63/100
#  - 19s - loss: 0.6860 - categorical_accuracy: 0.7910 - val_loss: 1.6269 - val_categorical_accuracy: 0.5382
# Epoch 64/100
#  - 18s - loss: 0.6741 - categorical_accuracy: 0.7942 - val_loss: 1.2230 - val_categorical_accuracy: 0.6445
# Epoch 65/100
#  - 17s - loss: 0.7100 - categorical_accuracy: 0.7858 - val_loss: 1.3915 - val_categorical_accuracy: 0.6013
# Epoch 66/100
#  - 17s - loss: 0.7669 - categorical_accuracy: 0.7586 - val_loss: 1.3455 - val_categorical_accuracy: 0.6047
# Epoch 67/100
#  - 17s - loss: 0.7606 - categorical_accuracy: 0.7695 - val_loss: 1.2311 - val_categorical_accuracy: 0.6179
# Epoch 68/100
#  - 17s - loss: 0.6288 - categorical_accuracy: 0.8057 - val_loss: 1.1013 - val_categorical_accuracy: 0.6512
# Epoch 69/100
#  - 17s - loss: 0.6332 - categorical_accuracy: 0.8054 - val_loss: 1.2763 - val_categorical_accuracy: 0.6047
# Epoch 70/100
#  - 17s - loss: 0.5721 - categorical_accuracy: 0.8254 - val_loss: 1.2243 - val_categorical_accuracy: 0.6379
# Epoch 71/100
#  - 17s - loss: 0.6049 - categorical_accuracy: 0.8176 - val_loss: 1.1690 - val_categorical_accuracy: 0.6687
# Epoch 72/100
#  - 17s - loss: 0.6492 - categorical_accuracy: 0.7967 - val_loss: 1.4707 - val_categorical_accuracy: 0.6047
# Epoch 73/100
#  - 17s - loss: 0.5617 - categorical_accuracy: 0.8282 - val_loss: 1.1511 - val_categorical_accuracy: 0.6611
# Epoch 74/100
#  - 17s - loss: 0.6224 - categorical_accuracy: 0.8166 - val_loss: 1.5509 - val_categorical_accuracy: 0.5349
# Epoch 75/100
#  - 17s - loss: 0.5588 - categorical_accuracy: 0.8319 - val_loss: 1.0443 - val_categorical_accuracy: 0.7010
# Epoch 76/100
#  - 18s - loss: 0.5480 - categorical_accuracy: 0.8285 - val_loss: 1.2120 - val_categorical_accuracy: 0.6279
# Epoch 77/100
#  - 18s - loss: 0.5197 - categorical_accuracy: 0.8403 - val_loss: 1.2656 - val_categorical_accuracy: 0.6545
# Epoch 78/100
#  - 17s - loss: 0.5349 - categorical_accuracy: 0.8380 - val_loss: 1.3751 - val_categorical_accuracy: 0.6013
# Epoch 79/100
#  - 17s - loss: 0.7536 - categorical_accuracy: 0.7828 - val_loss: 1.4662 - val_categorical_accuracy: 0.5947
# Epoch 80/100
#  - 18s - loss: 0.4626 - categorical_accuracy: 0.8666 - val_loss: 1.1636 - val_categorical_accuracy: 0.6744
# Epoch 81/100
#  - 17s - loss: 0.4405 - categorical_accuracy: 0.8686 - val_loss: 1.3317 - val_categorical_accuracy: 0.6080
# Epoch 82/100
#  - 18s - loss: 0.3948 - categorical_accuracy: 0.8818 - val_loss: 1.3169 - val_categorical_accuracy: 0.6344
# Epoch 83/100
#  - 18s - loss: 0.5774 - categorical_accuracy: 0.8337 - val_loss: 1.2707 - val_categorical_accuracy: 0.6013
# Epoch 84/100
#  - 17s - loss: 0.4001 - categorical_accuracy: 0.8804 - val_loss: 1.1390 - val_categorical_accuracy: 0.6512
# Epoch 85/100
#  - 17s - loss: 0.4837 - categorical_accuracy: 0.8505 - val_loss: 1.4370 - val_categorical_accuracy: 0.6047

# %% [markdown]
# Большой процент дропаута сильно помог с переубучением! Сохраним на состояние модели для последующих тестов.

# %%
model.save('best_model-augdata.h5')

# %% [markdown]
# #### Попробуем применить аугментацию наших изображений
#  - случайный поворот на 10 градусов
#  - случайное зуммирование на 10%
#  - случайное изменение яркости в диапозоне \[0.7, 1.3\]
#  - случайное горизонтальное отображение
#
# Это должно привести к более стабильным результатам. Используем предыдущую архитектуру сети, т.к. она дала самые лучшие результаты.

# %%
model = conv_model(size=3, lr=0.001, use_dropout=True, use_batchnorm=True, use_globalpool=True)
model.summary()
# Out:
# W1217 07:25:03.951596 140203217426240 nn_ops.py:4283] Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 112, 112, 64)      9472
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 112, 112, 64)      256
# _________________________________________________________________
# activation_6 (Activation)    (None, 112, 112, 64)      0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 56, 56, 128)       73856
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 56, 56, 128)       512
# _________________________________________________________________
# activation_7 (Activation)    (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 56, 56, 128)       147584
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 56, 56, 128)       512
# _________________________________________________________________
# activation_8 (Activation)    (None, 56, 56, 128)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 256)       295168
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 28, 28, 256)       1024
# _________________________________________________________________
# activation_9 (Activation)    (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 28, 28, 256)       590080
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# activation_10 (Activation)   (None, 28, 28, 256)       0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 256)       0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 37)                9509
# =================================================================
# Total params: 1,128,997
# Trainable params: 1,127,333
# Non-trainable params: 1,664
# _________________________________________________________________

# %%
early_stop = EarlyStopping(patience=10)

history_ = model.fit_generator(
            generator=train_generator,
            steps_per_epoch=train_generator.n // batch_size,
            validation_data=val_generator,
            validation_steps=val_generator.n // batch_size,
            epochs=100,
            verbose=2,
            callbacks=[early_stop])

plot_history([history_])
# Out:
# W1217 07:26:01.370959 140203217426240 deprecation.py:323] From /home/mikhailm/anaconda3/envs/reinf_learn/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1217 07:26:01.636710 140203217426240 module_wrapper.py:139] From /home/mikhailm/anaconda3/envs/reinf_learn/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W1217 07:26:01.858319 140203217426240 module_wrapper.py:139] From /home/mikhailm/anaconda3/envs/reinf_learn/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Epoch 1/100
#  - 198s - loss: 3.9683 - categorical_accuracy: 0.0353 - val_loss: 3.5945 - val_categorical_accuracy: 0.0469
# Epoch 2/100
#  - 113s - loss: 3.7136 - categorical_accuracy: 0.0406 - val_loss: 3.6835 - val_categorical_accuracy: 0.0432
# Epoch 3/100
#  - 113s - loss: 3.6233 - categorical_accuracy: 0.0518 - val_loss: 3.5277 - val_categorical_accuracy: 0.0465
# Epoch 4/100
#  - 113s - loss: 3.5740 - categorical_accuracy: 0.0547 - val_loss: 3.7913 - val_categorical_accuracy: 0.0399
# Epoch 5/100
#  - 113s - loss: 3.5126 - categorical_accuracy: 0.0676 - val_loss: 3.5540 - val_categorical_accuracy: 0.0631
# Epoch 6/100
#  - 114s - loss: 3.4805 - categorical_accuracy: 0.0723 - val_loss: 3.5656 - val_categorical_accuracy: 0.0532
# Epoch 7/100
#  - 112s - loss: 3.4420 - categorical_accuracy: 0.0766 - val_loss: 4.0896 - val_categorical_accuracy: 0.0432
# Epoch 8/100
#  - 113s - loss: 3.3906 - categorical_accuracy: 0.0855 - val_loss: 3.5302 - val_categorical_accuracy: 0.1030
# Epoch 9/100
#  - 114s - loss: 3.3584 - categorical_accuracy: 0.0903 - val_loss: 3.5366 - val_categorical_accuracy: 0.0631
# Epoch 10/100
#  - 113s - loss: 3.2890 - categorical_accuracy: 0.1057 - val_loss: 3.5959 - val_categorical_accuracy: 0.0365
# Epoch 11/100
#  - 113s - loss: 3.2385 - categorical_accuracy: 0.1130 - val_loss: 3.6863 - val_categorical_accuracy: 0.0532
# Epoch 12/100
#  - 113s - loss: 3.2084 - categorical_accuracy: 0.1253 - val_loss: 4.1625 - val_categorical_accuracy: 0.0594
# Epoch 13/100
#  - 113s - loss: 3.1271 - categorical_accuracy: 0.1378 - val_loss: 3.4316 - val_categorical_accuracy: 0.0731
# Epoch 14/100
#  - 113s - loss: 3.1120 - categorical_accuracy: 0.1446 - val_loss: 3.3271 - val_categorical_accuracy: 0.0698
# Epoch 15/100
#  - 112s - loss: 3.0250 - categorical_accuracy: 0.1573 - val_loss: 3.5289 - val_categorical_accuracy: 0.0764
# Epoch 16/100
#  - 113s - loss: 2.9876 - categorical_accuracy: 0.1681 - val_loss: 3.1487 - val_categorical_accuracy: 0.1462
# Epoch 17/100
#  - 112s - loss: 2.9666 - categorical_accuracy: 0.1800 - val_loss: 3.0868 - val_categorical_accuracy: 0.1362
# Epoch 18/100
#  - 113s - loss: 2.9072 - categorical_accuracy: 0.1841 - val_loss: 2.9481 - val_categorical_accuracy: 0.1860
# Epoch 19/100
#  - 113s - loss: 2.8638 - categorical_accuracy: 0.1995 - val_loss: 3.5629 - val_categorical_accuracy: 0.1096
# Epoch 20/100
#  - 113s - loss: 2.7810 - categorical_accuracy: 0.2152 - val_loss: 2.8779 - val_categorical_accuracy: 0.2292
# Epoch 21/100
#  - 113s - loss: 2.7263 - categorical_accuracy: 0.2354 - val_loss: 4.8824 - val_categorical_accuracy: 0.0498
# Epoch 22/100
#  - 113s - loss: 2.6928 - categorical_accuracy: 0.2385 - val_loss: 3.1755 - val_categorical_accuracy: 0.1429
# Epoch 23/100
#  - 113s - loss: 2.6526 - categorical_accuracy: 0.2488 - val_loss: 2.9291 - val_categorical_accuracy: 0.1906
# Epoch 24/100
#  - 113s - loss: 2.6025 - categorical_accuracy: 0.2626 - val_loss: 2.8223 - val_categorical_accuracy: 0.2392
# Epoch 25/100
#  - 113s - loss: 2.5354 - categorical_accuracy: 0.2873 - val_loss: 3.1025 - val_categorical_accuracy: 0.1395
# Epoch 26/100
#  - 113s - loss: 2.4868 - categorical_accuracy: 0.2906 - val_loss: 2.7975 - val_categorical_accuracy: 0.2326
# Epoch 27/100
#  - 113s - loss: 2.4782 - categorical_accuracy: 0.2926 - val_loss: 2.6939 - val_categorical_accuracy: 0.2824
# Epoch 28/100
#  - 113s - loss: 2.4186 - categorical_accuracy: 0.3016 - val_loss: 2.6432 - val_categorical_accuracy: 0.3023
# Epoch 29/100
#  - 113s - loss: 2.3594 - categorical_accuracy: 0.3095 - val_loss: 2.7193 - val_categorical_accuracy: 0.2425
# Epoch 30/100
#  - 114s - loss: 2.3332 - categorical_accuracy: 0.3245 - val_loss: 2.8533 - val_categorical_accuracy: 0.1860
# Epoch 31/100
#  - 113s - loss: 2.3031 - categorical_accuracy: 0.3338 - val_loss: 2.5885 - val_categorical_accuracy: 0.2791
# Epoch 32/100
#  - 114s - loss: 2.2365 - categorical_accuracy: 0.3500 - val_loss: 2.6105 - val_categorical_accuracy: 0.2857
# Epoch 33/100
#  - 113s - loss: 2.2110 - categorical_accuracy: 0.3517 - val_loss: 2.7320 - val_categorical_accuracy: 0.2359
# Epoch 34/100
#  - 111s - loss: 2.1303 - categorical_accuracy: 0.3742 - val_loss: 2.2785 - val_categorical_accuracy: 0.3281
# Epoch 35/100
#  - 112s - loss: 2.1431 - categorical_accuracy: 0.3752 - val_loss: 2.5656 - val_categorical_accuracy: 0.2924
# Epoch 36/100
#  - 112s - loss: 2.0801 - categorical_accuracy: 0.3784 - val_loss: 3.5604 - val_categorical_accuracy: 0.0864
# Epoch 37/100
#  - 112s - loss: 2.0393 - categorical_accuracy: 0.4058 - val_loss: 3.0253 - val_categorical_accuracy: 0.2990
# Epoch 38/100
#  - 111s - loss: 1.9946 - categorical_accuracy: 0.3983 - val_loss: 2.2332 - val_categorical_accuracy: 0.3654
# Epoch 39/100
#  - 112s - loss: 1.9720 - categorical_accuracy: 0.4129 - val_loss: 2.2917 - val_categorical_accuracy: 0.3854
# Epoch 40/100
#  - 112s - loss: 1.9400 - categorical_accuracy: 0.4240 - val_loss: 2.7990 - val_categorical_accuracy: 0.2027
# Epoch 41/100
#  - 111s - loss: 1.9190 - categorical_accuracy: 0.4311 - val_loss: 2.2026 - val_categorical_accuracy: 0.3621
# Epoch 42/100
#  - 112s - loss: 1.8794 - categorical_accuracy: 0.4380 - val_loss: 2.2427 - val_categorical_accuracy: 0.3488
# Epoch 43/100
#  - 112s - loss: 1.8112 - categorical_accuracy: 0.4503 - val_loss: 2.1270 - val_categorical_accuracy: 0.4286
# Epoch 44/100
#  - 112s - loss: 1.7773 - categorical_accuracy: 0.4653 - val_loss: 1.9662 - val_categorical_accuracy: 0.4585
# Epoch 45/100
#  - 112s - loss: 1.7366 - categorical_accuracy: 0.4742 - val_loss: 2.2167 - val_categorical_accuracy: 0.3594
# Epoch 46/100
#  - 112s - loss: 1.7182 - categorical_accuracy: 0.4884 - val_loss: 2.4643 - val_categorical_accuracy: 0.2924
# Epoch 47/100
#  - 112s - loss: 1.6557 - categorical_accuracy: 0.5051 - val_loss: 1.8460 - val_categorical_accuracy: 0.4518
# Epoch 48/100
#  - 112s - loss: 1.6692 - categorical_accuracy: 0.4946 - val_loss: 1.8836 - val_categorical_accuracy: 0.4718
# Epoch 49/100
#  - 112s - loss: 1.6159 - categorical_accuracy: 0.5048 - val_loss: 2.0050 - val_categorical_accuracy: 0.4352
# Epoch 50/100
#  - 111s - loss: 1.5963 - categorical_accuracy: 0.5146 - val_loss: 1.6953 - val_categorical_accuracy: 0.4950
# Epoch 51/100
#  - 112s - loss: 1.5925 - categorical_accuracy: 0.5210 - val_loss: 2.1559 - val_categorical_accuracy: 0.3920
# Epoch 52/100
#  - 112s - loss: 1.5259 - categorical_accuracy: 0.5389 - val_loss: 2.0980 - val_categorical_accuracy: 0.3987
# Epoch 53/100
#  - 112s - loss: 1.4955 - categorical_accuracy: 0.5449 - val_loss: 1.6583 - val_categorical_accuracy: 0.5415
# Epoch 54/100
#  - 112s - loss: 1.4762 - categorical_accuracy: 0.5533 - val_loss: 1.5382 - val_categorical_accuracy: 0.5382
# Epoch 55/100
#  - 111s - loss: 1.4309 - categorical_accuracy: 0.5690 - val_loss: 2.0348 - val_categorical_accuracy: 0.3887
# Epoch 56/100
#  - 111s - loss: 1.4144 - categorical_accuracy: 0.5686 - val_loss: 1.4123 - val_categorical_accuracy: 0.6094
# Epoch 57/100
#  - 112s - loss: 1.3925 - categorical_accuracy: 0.5698 - val_loss: 1.8638 - val_categorical_accuracy: 0.4751
# Epoch 58/100
#  - 112s - loss: 1.3680 - categorical_accuracy: 0.5858 - val_loss: 1.8628 - val_categorical_accuracy: 0.4352
# Epoch 59/100
#  - 111s - loss: 1.3411 - categorical_accuracy: 0.5928 - val_loss: 1.6670 - val_categorical_accuracy: 0.4718
# Epoch 60/100
#  - 112s - loss: 1.2965 - categorical_accuracy: 0.6059 - val_loss: 1.9137 - val_categorical_accuracy: 0.4385
# Epoch 61/100
#  - 112s - loss: 1.2655 - categorical_accuracy: 0.6073 - val_loss: 1.7116 - val_categorical_accuracy: 0.5116
# Epoch 62/100
#  - 113s - loss: 1.2678 - categorical_accuracy: 0.6123 - val_loss: 1.5389 - val_categorical_accuracy: 0.5249
# Epoch 63/100
#  - 112s - loss: 1.2290 - categorical_accuracy: 0.6134 - val_loss: 1.7471 - val_categorical_accuracy: 0.5382
# Epoch 64/100
#  - 112s - loss: 1.2362 - categorical_accuracy: 0.6228 - val_loss: 2.7997 - val_categorical_accuracy: 0.3289
# Epoch 65/100
#  - 112s - loss: 1.2016 - categorical_accuracy: 0.6306 - val_loss: 1.6889 - val_categorical_accuracy: 0.5017
# Epoch 66/100
#  - 111s - loss: 1.2232 - categorical_accuracy: 0.6317 - val_loss: 1.5529 - val_categorical_accuracy: 0.5349

# %% [markdown]
# Как видно из графика сильно это не помогло. Предположение: уменьшить learning rate, возможно модель зависла на плато и сойдется еще чуть-чуть. Используем lr=0.0003, как советовал Andrej Karpathy в своем [твиттере](https://twitter.com/karpathy/status/801621764144971776) =D

# %%
model.optimizer = Adam(lr=0.0003)

# %%
early_stop = EarlyStopping(patience=10)

history_ = model.fit_generator(
            generator=train_generator,
            steps_per_epoch=train_generator.n // batch_size,
            validation_data=val_generator,
            validation_steps=val_generator.n // batch_size,
            epochs=20,
            verbose=2,
            callbacks=[early_stop])

plot_history([history_])
# Out:
# Epoch 1/20
#  - 113s - loss: 0.9489 - categorical_accuracy: 0.7220 - val_loss: 1.3387 - val_categorical_accuracy: 0.5880
# Epoch 2/20
#  - 114s - loss: 0.8085 - categorical_accuracy: 0.7553 - val_loss: 1.5844 - val_categorical_accuracy: 0.5914
# Epoch 3/20
#  - 113s - loss: 0.7608 - categorical_accuracy: 0.7654 - val_loss: 1.3064 - val_categorical_accuracy: 0.6213
# Epoch 4/20
#  - 114s - loss: 0.7710 - categorical_accuracy: 0.7587 - val_loss: 1.0489 - val_categorical_accuracy: 0.7076
# Epoch 5/20
#  - 112s - loss: 0.8355 - categorical_accuracy: 0.7449 - val_loss: 1.1500 - val_categorical_accuracy: 0.6213
# Epoch 6/20
#  - 112s - loss: 0.7462 - categorical_accuracy: 0.7657 - val_loss: 1.5887 - val_categorical_accuracy: 0.6578
# Epoch 7/20
#  - 113s - loss: 0.8778 - categorical_accuracy: 0.7351 - val_loss: 1.2737 - val_categorical_accuracy: 0.5847
# Epoch 8/20
#  - 112s - loss: 0.8050 - categorical_accuracy: 0.7496 - val_loss: 1.3155 - val_categorical_accuracy: 0.6013
# Epoch 9/20
#  - 112s - loss: 0.7751 - categorical_accuracy: 0.7631 - val_loss: 1.2869 - val_categorical_accuracy: 0.5980
# Epoch 10/20
#  - 112s - loss: 0.7357 - categorical_accuracy: 0.7684 - val_loss: 1.1918 - val_categorical_accuracy: 0.6379
# Epoch 11/20
#  - 112s - loss: 0.6743 - categorical_accuracy: 0.7859 - val_loss: 1.0720 - val_categorical_accuracy: 0.6813
# Epoch 12/20
#  - 112s - loss: 0.7194 - categorical_accuracy: 0.7763 - val_loss: 1.2900 - val_categorical_accuracy: 0.6013
# Epoch 13/20
#  - 112s - loss: 0.7026 - categorical_accuracy: 0.7814 - val_loss: 1.2069 - val_categorical_accuracy: 0.6379
# Epoch 14/20
#  - 113s - loss: 0.7443 - categorical_accuracy: 0.7722 - val_loss: 1.1567 - val_categorical_accuracy: 0.6545

# %% [markdown]
# +5% точности на валидационной выборке! Неплохо. Возможно еще раз уменьшить lr... но по 2 минуты на эпоху слишком долго... Остановимся на этом и сохраним модель.

# %%
model.save('best_model+augdata.h5')

# %% [markdown]
# А что если модель без применения аугментации так же хороша? Проверим!

# %%
best_model = load_model('best_model-augdata.h5')
best_model.optimizer = Adam(lr=0.00001)

# %%
early_stop = EarlyStopping(patience=10)

history_ = best_model.fit_generator(
            generator=train_generator,
            steps_per_epoch=train_generator.n // batch_size,
            validation_data=val_generator,
            validation_steps=val_generator.n // batch_size,
            epochs=20,
            verbose=2,
            callbacks=[early_stop])

plot_history([history_])
# Out:
# Epoch 1/20
#  - 20s - loss: 0.4797 - categorical_accuracy: 0.8623 - val_loss: 1.6537 - val_categorical_accuracy: 0.5880
# Epoch 2/20
#  - 17s - loss: 0.3960 - categorical_accuracy: 0.8837 - val_loss: 1.1191 - val_categorical_accuracy: 0.6977
# Epoch 3/20
#  - 17s - loss: 0.3330 - categorical_accuracy: 0.9045 - val_loss: 1.3055 - val_categorical_accuracy: 0.6047
# Epoch 4/20
#  - 17s - loss: 0.2981 - categorical_accuracy: 0.9181 - val_loss: 1.1355 - val_categorical_accuracy: 0.6645
# Epoch 5/20
#  - 17s - loss: 0.2728 - categorical_accuracy: 0.9224 - val_loss: 1.6386 - val_categorical_accuracy: 0.5947
# Epoch 6/20
#  - 17s - loss: 0.3948 - categorical_accuracy: 0.8871 - val_loss: 1.3062 - val_categorical_accuracy: 0.6179
# Epoch 7/20
#  - 17s - loss: 0.3710 - categorical_accuracy: 0.8980 - val_loss: 1.3395 - val_categorical_accuracy: 0.6412
# Epoch 8/20
#  - 18s - loss: 0.2401 - categorical_accuracy: 0.9355 - val_loss: 1.5340 - val_categorical_accuracy: 0.6146
# Epoch 9/20
#  - 18s - loss: 0.3770 - categorical_accuracy: 0.9027 - val_loss: 1.2427 - val_categorical_accuracy: 0.6279
# Epoch 10/20
#  - 17s - loss: 0.3385 - categorical_accuracy: 0.9061 - val_loss: 1.1538 - val_categorical_accuracy: 0.6531
# Epoch 11/20
#  - 17s - loss: 0.2088 - categorical_accuracy: 0.9431 - val_loss: 1.2382 - val_categorical_accuracy: 0.6744
# Epoch 12/20
#  - 17s - loss: 0.2606 - categorical_accuracy: 0.9299 - val_loss: 1.4277 - val_categorical_accuracy: 0.6047

# %% [markdown]
# Нет, не вышло. Аугментация данных все таки приносит свои плоды.

# %% [markdown]
# ### Тестирование

# %% [markdown]
# Загрузим наши лучшие модели.

# %%
best_model_1 = load_model('1.h5')
best_model_2 = load_model('2.h5')
best_model_3 = load_model('best_model-augdata.h5')
best_model_4 = load_model('best_model+augdata.h5')
# Out:
# WARNING:tensorflow:From /home/mikhailm/anaconda3/envs/deeplearn/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.

# %% [markdown]
# Генератор с тестовыми данными

# %%
test_data = pandas.read_csv('../test_pets.csv', usecols=['Category', 'Path'])
test_datagen = ImageDataGenerator(rescale=1. / 255)
test_generator = test_datagen.flow_from_dataframe(
        dataframe=val_data,
        directory='.',
        x_col='Path',
        y_col='Category',
        class_mode='categorical',
        target_size=input_shape,
        interpolation='bicubic',
        batch_size=batch_size)
# Out:
# Found 333 validated image filenames belonging to 37 classes.

# %% [markdown]
# Проверим ошибку и точность обеих моделей. Результат очевиден.

# %%
history_1 = best_model_1.evaluate_generator(
    test_generator,
    steps=test_generator.n // batch_size,
    verbose=1)

history_2 = best_model_2.evaluate_generator(
    test_generator,
    steps=test_generator.n // batch_size,
    verbose=1)

history_3 = best_model_3.evaluate_generator(
    test_generator,
    steps=test_generator.n // batch_size,
    verbose=1)

history_4 = best_model_4.evaluate_generator(
    test_generator,
    steps=test_generator.n // batch_size,
    verbose=1)

print(f'1:\n - test loss: {history_1[0]}, test accuracy: {history_1[1]}')
print(f'2:\n - test loss: {history_2[0]}, test accuracy: {history_2[1]}')
print(f'3:\n - test loss: {history_3[0]}, test accuracy: {history_3[1]}')
print(f'4:\n - test loss: {history_4[0]}, test accuracy: {history_4[1]}')
# Out:
# 10/10 [==============================] - 1s 79ms/step
# 10/10 [==============================] - 1s 95ms/step
# 10/10 [==============================] - 1s 83ms/step
# 10/10 [==============================] - 1s 89ms/step
# 1:
#  - test loss: 8.397007790118753, test accuracy: 0.16943521607060766
# 2:
#  - test loss: 2.655903912065829, test accuracy: 0.3588039868099745
# 3:
#  - test loss: 1.2996498271080346, test accuracy: 0.6212624594618712
# 4:
#  - test loss: 1.0639658837619415, test accuracy: 0.66777408756687

# %%
sample = test_generator.next()
image_array = sample[0]
categories_dict = {value: key for key, value in test_generator.class_indices.items()}
category = categories_dict[np.argmax(sample[1][0])]

predictions_1 = best_model_1.predict(image_array)[0]
predictions_2 = best_model_2.predict(image_array)[0]
predictions_3 = best_model_3.predict(image_array)[0]
predictions_4 = best_model_4.predict(image_array)[0]

best_args_1 = np.argsort(predictions_1)[::-1][:3]
best_args_2 = np.argsort(predictions_2)[::-1][:3]
best_args_3 = np.argsort(predictions_3)[::-1][:3]
best_args_4 = np.argsort(predictions_4)[::-1][:3]

print(f'Original: {category}\n')

print('1')
for i in best_args_1:
    print(' -', categories_dict[i], predictions_1[i])

print('\n2')
for i in best_args_2:
    print(' -', categories_dict[i], predictions_2[i])
    
print('\n3')
for i in best_args_3:
    print(' -', categories_dict[i], predictions_3[i])
    
print('\n4')
for i in best_args_4:
    print(' -', categories_dict[i], predictions_4[i])

plt.imshow(image_array[0])
# Out:
# Original: basset_hound
#
# 1
#  - american_pit_bull_terrier 0.901869
#  - saint_bernard 0.053291954
#  - beagle 0.040868543
#
# 2
#  - basset_hound 0.89700705
#  - american_pit_bull_terrier 0.07242166
#  - saint_bernard 0.01048784
#
# 3
#  - basset_hound 0.5467195
#  - beagle 0.32127753
#  - boxer 0.0801156
#
# 4
#  - basset_hound 0.5987823
#  - beagle 0.26649556
#  - saint_bernard 0.04203651
